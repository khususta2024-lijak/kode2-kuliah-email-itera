# %%
def vigenere_cipher_encrypt(plain_text, key):
    encrypted_text = ""
    key_index = 0
    for char in plain_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Encrypt character using Vigenere cipher formula
            encrypted_char = chr(((ord(char) - 65) + (ord(key_char) - 65)) % 26 + 65)
            encrypted_text += encrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            encrypted_text += char
    return encrypted_text

def vigenere_cipher_decrypt(encrypted_text, key):
    decrypted_text = ""
    key_index = 0
    for char in encrypted_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Decrypt character using Vigenere cipher formula
            decrypted_char = chr(((ord(char) - 65) - (ord(key_char) - 65)) % 26 + 65)
            decrypted_text += decrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            decrypted_text += char
    return decrypted_text

# Example usage:
plain_text = "HELLO"
key = "KEY"
encrypted_text = vigenere_cipher_encrypt(plain_text, key)
print("Encrypted Text:", encrypted_text)
decrypted_text = vigenere_cipher_decrypt(encrypted_text, key)
print("Decrypted Text:", decrypted_text)
# Out:
# Encrypted Text: RIJVS
# Decrypted Text: HELLO

# %%
def vigenere_cipher_encrypt_standard(plain_text, key):
    encrypted_text = ""
    key_index = 0
    for char in plain_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Encrypt character using Vigenere cipher formula
            encrypted_char = chr(((ord(char) - 65) + (ord(key_char) - 65)) % 26 + 65)
            encrypted_text += encrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            encrypted_text += char
    return encrypted_text

def vigenere_cipher_decrypt_standard(encrypted_text, key):
    decrypted_text = ""
    key_index = 0
    for char in encrypted_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Decrypt character using Vigenere cipher formula
            decrypted_char = chr(((ord(char) - 65) - (ord(key_char) - 65)) % 26 + 65)
            decrypted_text += decrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            decrypted_text += char
    return decrypted_text

# %%
import inspect

def vigenere_cipher_encrypt_standard(plain_text, key):
    encrypted_text = ""
    key_index = 0
    for char in plain_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Encrypt character using Vigenere cipher formula
            encrypted_char = chr(((ord(char) - 65) + (ord(key_char) - 65)) % 26 + 65)
            encrypted_text += encrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            encrypted_text += char
    return encrypted_text

def vigenere_cipher_decrypt_standard(encrypted_text, key):
    decrypted_text = ""
    key_index = 0
    for char in encrypted_text:
        if char.isalpha():
            # Convert character to uppercase for simplicity
            char = char.upper()
            key_char = key[key_index % len(key)].upper()
            # Decrypt character using Vigenere cipher formula
            decrypted_char = chr(((ord(char) - 65) - (ord(key_char) - 65)) % 26 + 65)
            decrypted_text += decrypted_char
            key_index += 1
        else:
            # Non-alphabetic characters remain unchanged
            decrypted_text += char
    return decrypted_text

# Mendapatkan teks kode dari fungsi vigenere_cipher_encrypt_standard
encrypt_code = inspect.getsource(vigenere_cipher_encrypt_standard)

# Mendapatkan teks kode dari fungsi vigenere_cipher_decrypt_standard
decrypt_code = inspect.getsource(vigenere_cipher_decrypt_standard)

# Menampilkan teks kode
print("Kode vigenere_cipher_encrypt_standard:")
print(encrypt_code)

print("Kode vigenere_cipher_decrypt_standard:")
print(decrypt_code)
# Out:
# Kode vigenere_cipher_encrypt_standard:
# def vigenere_cipher_encrypt_standard(plain_text, key):
#     encrypted_text = ""
#     key_index = 0
#     for char in plain_text:
#         if char.isalpha():
#             # Convert character to uppercase for simplicity
#             char = char.upper()
#             key_char = key[key_index % len(key)].upper()
#             # Encrypt character using Vigenere cipher formula
#             encrypted_char = chr(((ord(char) - 65) + (ord(key_char) - 65)) % 26 + 65)
#             encrypted_text += encrypted_char
#             key_index += 1
#         else:
#             # Non-alphabetic characters remain unchanged
#             encrypted_text += char
#     return encrypted_text
#
# Kode vigenere_cipher_decrypt_standard:
# def vigenere_cipher_decrypt_standard(encrypted_text, key):
#     decrypted_text = ""
#     key_index = 0
#     for char in encrypted_text:
#         if char.isalpha():
# ...

# %%
def vigenere_cipher_encrypt_ascii(plain_text, key):
    encrypted_text = ""
    key_index = 0
    for char in plain_text:
        key_char = key[key_index % len(key)]
        encrypted_char = chr((ord(char) + ord(key_char)) % 256)
        encrypted_text += encrypted_char
        key_index += 1
    return encrypted_text

def vigenere_cipher_decrypt_ascii(encrypted_text, key):
    decrypted_text = ""
    key_index = 0
    for char in encrypted_text:
        key_char = key[key_index % len(key)]
        decrypted_char = chr((ord(char) - ord(key_char)) % 256)
        decrypted_text += decrypted_char
        key_index += 1
    return decrypted_text

# %%
def vigenere_cipher_encrypt_custom(plain_text, key, alphabet):
    encrypted_text = ""
    key_index = 0
    for char in plain_text:
        if char in alphabet:
            char_index = alphabet.index(char)
            key_char = key[key_index % len(key)]
            key_index += 1
            key_char_index = alphabet.index(key_char)
            encrypted_char_index = (char_index + key_char_index) % len(alphabet)
            encrypted_char = alphabet[encrypted_char_index]
            encrypted_text += encrypted_char
        else:
            encrypted_text += char
    return encrypted_text

def vigenere_cipher_decrypt_custom(encrypted_text, key, alphabet):
    decrypted_text = ""
    key_index = 0
    for char in encrypted_text:
        if char in alphabet:
            char_index = alphabet.index(char)
            key_char = key[key_index % len(key)]
            key_index += 1
            key_char_index = alphabet.index(key_char)
            decrypted_char_index = (char_index - key_char_index) % len(alphabet)
            decrypted_char = alphabet[decrypted_char_index]
            decrypted_text += decrypted_char
        else:
            decrypted_text += char
    return decrypted_text
