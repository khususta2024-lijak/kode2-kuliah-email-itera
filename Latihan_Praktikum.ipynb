# %%
import numpy as np

#fungsi aktivasi yang akan dipanggil
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# mendefinisikan class neural network
class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        # menginisialisasi  bobot dari input ke hidden
        self.weights_input_hidden = np.array([[0.5, 0.2, -0.3, 0.3, 0.1], [0.7, -0.4, 0.6, 0.8, 0.1]])

        # menginisialisasi  bobot dari hidden ke output
        self.weights_hidden_output = np.array([[0.1, -0.2], [0.4, 0.3], [0.5, 0.7], [0.5, -0.7], [0.3, 0.6]])

        # menginisialisasi bias
        self.bias_hidden = np.array([0.7, 0.7, 0.7, 0.7, 0.7])  # Bias untuk hiden
        self.bias_output = np.array([0.9, 0.9])       # Bias untuk output

    def forward(self, inputs):
        # Forward propagation
        self.hidden_input = np.dot(inputs, self.weights_input_hidden) + self.bias_hidden
        self.hidden_output = sigmoid(self.hidden_input)
        self.output_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
        self.predicted_output = sigmoid(self.output_input)
        return self.predicted_output

    def backward(self, inputs, target, learning_rate):
        # Backpropagation
        error = target - self.predicted_output
        delta_output = error * sigmoid_derivative(self.predicted_output)

        error_hidden = delta_output.dot(self.weights_hidden_output.T)
        delta_hidden = error_hidden * sigmoid_derivative(self.hidden_output)

        # Update weights
        self.weights_hidden_output += np.outer(self.hidden_output, delta_output) * learning_rate
        self.weights_input_hidden += np.outer(inputs, delta_hidden) * learning_rate

    def train(self, training_data, targets, epochs, learning_rate):
        for epoch in range(epochs):
            total_error = 0  # Initialize total error for the epoch
            for i in range(len(training_data)):
                inputs = training_data[i]
                target = targets[i]
                self.forward(inputs)
                self.backward(inputs, target, learning_rate)
                total_error += np.mean(np.square(target - self.predicted_output))  # Squared Error


            # Print error setiap 100 iterasi aja
            if epoch % 5 == 0:
                print(f"\nBobot dari input ke hidden:\n{nn.weights_input_hidden}")
                print(f"Epoch {epoch}, Average Error: {total_error / len(training_data)}")
                print(f"\nBobot dari input ke hidden:\n{nn.weights_input_hidden}")


    def predict(self, inputs):
        return self.forward(inputs)

# Input atau nilai x nya.
training_data = np.array([[0, 5]])
targets = np.array([2])

input_size = 2
hidden_size = 5
output_size = 1
learning_rate = 0.99
epochs = 100

nn = NeuralNetwork(input_size, hidden_size, output_size)
nn.train(training_data, targets, epochs, learning_rate)

# Test network
for inputs in training_data:
    prediction = nn.predict(inputs)
    print(f"Input: {inputs}, Predicted Output: {prediction}")
# Out:
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.69753336 -0.31574721  0.62293159  0.79530256  0.23826128]]
# Epoch 0, Average Error: 1.3498424386802785
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.69753336 -0.31574721  0.62293159  0.79530256  0.23826128]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.70453876 -0.06750459  0.6673989   0.79650214  0.3977657 ]]
# Epoch 5, Average Error: 1.0644452299275455
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.70453876 -0.06750459  0.6673989   0.79650214  0.3977657 ]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71054507  0.05693929  0.6862468   0.7995359   0.44835189]]
# Epoch 10, Average Error: 1.0351707547673947
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71054507  0.05693929  0.6862468   0.7995359   0.44835189]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71513675  0.12950695  0.69822981  0.80208491  0.47755229]]
# Epoch 15, Average Error: 1.0242118647688176
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71513675  0.12950695  0.69822981  0.80208491  0.47755229]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71886469  0.17804499  0.70703007  0.80424145  0.49782115]]
# Epoch 20, Average Error: 1.0185007448043084
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.71886469  0.17804499  0.70703007  0.80424145  0.49782115]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72201616  0.21357087  0.71398841  0.80611     0.51323308]]
# Epoch 25, Average Error: 1.0149898261711434
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72201616  0.21357087  0.71398841  0.80611     0.51323308]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72475393  0.24116171  0.71974302  0.80776119  0.52560745]]
# Epoch 30, Average Error: 1.0126089440273072
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72475393  0.24116171  0.71974302  0.80776119  0.52560745]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72717912  0.26349053  0.72464828  0.80924277  0.53590966]]
# Epoch 35, Average Error: 1.0108861083285081
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.72717912  0.26349053  0.72464828  0.80924277  0.53590966]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7293591   0.28211142  0.72892173  0.8105882   0.54471178]]
# Epoch 40, Average Error: 1.0095805819720138
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7293591   0.28211142  0.72892173  0.8105882   0.54471178]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73134111  0.29799757  0.73270666  0.81182178  0.55237998]]
# Epoch 45, Average Error: 1.0085565544530601
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73134111  0.29799757  0.73270666  0.81182178  0.55237998]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73315966  0.31179414  0.7361025   0.81296174  0.55916235]]
# Epoch 50, Average Error: 1.0077315153499824
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73315966  0.31179414  0.7361025   0.81296174  0.55916235]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73484077  0.3239485   0.73918112  0.81402208  0.56523451]]
# Epoch 55, Average Error: 1.0070524040900142
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73484077  0.3239485   0.73918112  0.81402208  0.56523451]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7364046   0.33478233  0.74199613  0.81501382  0.57072521]]
# Epoch 60, Average Error: 1.006483527021062
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7364046   0.33478233  0.74199613  0.81501382  0.57072521]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73786708  0.34453393  0.74458864  0.8159458   0.57573155]]
# Epoch 65, Average Error: 1.005999978615243
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73786708  0.34453393  0.74458864  0.8159458   0.57573155]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73924104  0.35338429  0.74699084  0.8168252   0.58032849]]
# Epoch 70, Average Error: 1.005583845872315
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.73924104  0.35338429  0.74699084  0.8168252   0.58032849]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74053696  0.36147382  0.7492284   0.81765797  0.5845751 ]]
# Epoch 75, Average Error: 1.005221911623921
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74053696  0.36147382  0.7492284   0.81765797  0.5845751 ]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74176355  0.36891344  0.75132216  0.81844906  0.58851868]]
# Epoch 80, Average Error: 1.004904208243433
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74176355  0.36891344  0.75132216  0.81844906  0.58851868]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7429281   0.37579217  0.75328923  0.81920267  0.59219773]]
# Epoch 85, Average Error: 1.004623075449121
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7429281   0.37579217  0.75328923  0.81920267  0.59219773]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7440368   0.38218245  0.75514384  0.81992238  0.59564393]]
# Epoch 90, Average Error: 1.0043725283055451
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.7440368   0.38218245  0.75514384  0.81992238  0.59564393]]
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74509492  0.38814396  0.75689797  0.82061125  0.59888369]]
# Epoch 95, Average Error: 1.0041478223772904
#
# Bobot dari input ke hidden:
# [[ 0.5         0.2        -0.3         0.3         0.1       ]
#  [ 0.74509492  0.38814396  0.75689797  0.82061125  0.59888369]]
# Input: [0 5], Predicted Output: [0.99804229 0.99801645]

# %%
import numpy as np

#fungsi aktivasi yang akan dipanggil
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# mendefinisikan class neural network
class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        # menginisialisasi  bobot dari input ke hidden
        self.weights_input_hidden = np.array([[0.5, 0.2, -0.3, 0.3], [0.7, -0.4, 0.6, 0.8]])

        # menginisialisasi  bobot dari hidden ke output
        self.weights_hidden_output = np.array([[0.1, -0.2], [0.4, 0.3], [0.5, 0.7], [0.5, -0.7], [0.3, 0.6]])

        # menginisialisasi bias
        self.bias_hidden = np.array([0.7, 0.7, 0.7, 0.7])  # Bias untuk hiden, adjusted to match the number of hidden nodes
        self.bias_output = np.array([0.9, 0.9])       # Bias untuk output

    def forward(self, inputs):
        # Forward propagation
        self.hidden_input = np.dot(inputs, self.weights_input_hidden) + self.bias_hidden
        self.hidden_output = sigmoid(self.hidden_input)
        self.output_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
        self.predicted_output = sigmoid(self.output_input)
        return self.predicted_output

    def backward(self, inputs, target, learning_rate):
        # Backpropagation
        error = target - self.predicted_output
        delta_output = error * sigmoid_derivative(self.predicted_output)

        error_hidden = delta_output.dot(self.weights_hidden_output.T)
        delta_hidden = error_hidden * sigmoid_derivative(self.hidden_output)

        # Update weights
        self.weights_hidden_output += np.outer(self.hidden_output, delta_output) * learning_rate
        self.weights_input_hidden += np.outer(inputs, delta_hidden) * learning_rate

    def train(self, training_data, targets, epochs, learning_rate):
        for epoch in range(epochs):
            total_error = 0  # Initialize total error for the epoch
            for i in range(len(training_data)):
                inputs = training_data[i]
                target = targets[i]
                self.forward(inputs)
                self.backward(inputs, target, learning_rate)
                total_error += np.mean(np.square(target - self.predicted_output))  # Squared Error


            # Print error setiap 100 iterasi aja
            if epoch % 5 == 0:
                print(f"\nBobot dari input ke hidden:\n{nn.weights_input_hidden}")
                print(f"Epoch {epoch}, Average Error: {total_error / len(training_data)}")
                print(f"\nBobot dari input ke hidden:\n{nn.weights_input_hidden}")


    def predict(self, inputs):
        return self.forward(inputs)

# Input atau nilai x nya.
training_data = np.array([[0, 5]])
targets = np.array([2])

input_size = 2
hidden_size = 5 # Adjusted hidden size to match the weights
output_size = 1
learning_rate = 0.99
epochs = 100

nn = NeuralNetwork(input_size, hidden_size, output_size)
nn.train(training_data, targets, epochs, learning_rate)

# Test network
for inputs in training_data:
    prediction = nn.predict(inputs)
    print(f"Input: {inputs}, Predicted Output: {prediction}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6a98452d92b5> in <cell line: 75>()
#      73
#      74 nn = NeuralNetwork(input_size, hidden_size, output_size)
# ---> 75 nn.train(training_data, targets, epochs, learning_rate)
#      76
#      77 # Test network
#
# <ipython-input-13-6a98452d92b5> in train(self, training_data, targets, epochs, learning_rate)
#      47                 inputs = training_data[i]
#      48                 target = targets[i]
# ---> 49                 self.forward(inputs)
#      50                 self.backward(inputs, target, learning_rate)
#      51                 total_error += np.mean(np.square(target - self.predicted_output))  # Squared Error
#
# <ipython-input-13-6a98452d92b5> in forward(self, inputs)
#      25         self.hidden_input = np.dot(inputs, self.weights_input_hidden) + self.bias_hidden
#      26         self.hidden_output = sigmoid(self.hidden_input)
# ---> 27         self.output_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
#      28         self.predicted_output = sigmoid(self.output_input)
#      29         return self.predicted_output
#
# ValueError: shapes (4,) and (5,2) not aligned: 4 (dim 0) != 5 (dim 0)
