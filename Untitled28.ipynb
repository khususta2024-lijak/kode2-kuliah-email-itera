# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.2 MB/s eta 0:00:00
# ...

# %%
from glob import glob
import os
import mne
import numpy as np
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/TA
# Out:
# /content/drive/MyDrive/TA

# %%
all_file_path=glob('/content/drive/MyDrive/TA/chb01/chb01_03.edf')
print(len(all_file_path))
# Out:
# 1

# %%
all_file_path[0]
# Out:
# '/content/drive/MyDrive/TA/chb01/chb01_03.edf'

# %%
healthy_file_path=[i for i in all_file_path if 'h' in i.split('/')[1]] # Use forward slash as the delimiter
patient_file_path=[i for i in all_file_path if 's' in i.split('/')[1]] # Use forward slash as the delimiter
print(len(healthy_file_path),len(patient_file_path))
# Out:
# 0 0

# %%
from array import array
def read_data(file_path):
data=mne.io.read_raw_edf(file_path,preload=True)
    data.set_eeg_reference()
    data.filter(l_freq=0.5, h_freq=45)
    epochs=mne.make_fixed_length_epochs(data, duration=5, overlap=1)
    array=epochs.get_data()
    return array
# Out:
#   File "<ipython-input-11-c4cd6fb1428c>", line 3
#     data=mne.io.read_raw_edf(file_path,preload=True)
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
from array import array
def read_data(file_path):
    data=mne.io.read_raw_edf(file_path,preload=True) # Indent this line
    data.set_eeg_reference() # Indent this line
    data.filter(l_freq=0.5, h_freq=45) # Indent this line
    epochs=mne.make_fixed_length_epochs(data, duration=5, overlap=1) # Indent this line
    array=epochs.get_data() # Indent this line
    return array # Indent this line

# %%
sample_data=read_data(healthy_file_path[0])
sample_data.shape #no of epoch, channel, length of signal
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-fc59f2b177e2> in <cell line: 1>()
# ----> 1 sample_data=read_data(healthy_file_path[0])
#       2 sample_data.shape #no of epoch, channel, length of signal
#
# IndexError: list index out of range

# %%
print(all_file_path) # Print all_file_path to check its contents
healthy_file_path=[i for i in all_file_path if 'h' in i.split('/')[1]] # Use forward slash as the delimiter
patient_file_path=[i for i in all_file_path if 's' in i.split('/')[1]] # Use forward slash as the delimiter
print(len(healthy_file_path),len(patient_file_path))
# Out:
# ['/content/drive/MyDrive/TA/chb01/chb01_03.edf']
# 0 0

# %%
sample_data=read_data(healthy_file_path[0]) # Make sure that this cell is executed and that there are no errors
sample_data.shape #no of epoch, channel, length of signal
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-ab0cfe0048e7> in <cell line: 1>()
# ----> 1 sample_data=read_data(healthy_file_path[0]) # Make sure that this cell is executed and that there are no errors
#       2 sample_data.shape #no of epoch, channel, length of signal
#
# IndexError: list index out of range

# %%
sample_data.shape #no of epoch, channel, length of signal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5c2ac2bd8803> in <cell line: 1>()
# ----> 1 sample_data.shape #no of epoch, channel, length of signal
#
# NameError: name 'sample_data' is not defined

# %%
print(all_file_path)
# Out:
# ['/content/drive/MyDrive/TA/chb01/chb01_03.edf']

# %%
# %%capture
control_epoch_array=[read_data(i) for i in healthy_file_path]
patient_epoch_array=[read_data(i) for i in patient_file_path]

# %%
control_epoch_array[0].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-9d85bc7da74b> in <cell line: 1>()
# ----> 1 control_epoch_array[0].shape
#
# IndexError: list index out of range

# %%
control_epoch_labels=[len(i)*[0] for i control_epoch_array]
patient_epoch_array=[len(i)*[1] for i in patient_epoch_array]
len(control_epoch_labels), len(patient_epoch_labels
# Out:
#   File "<ipython-input-21-73f258f9baaf>", line 1
#     control_epoch_labels=[len(i)*[0] for i control_epoch_array]
#                                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data_list=control_epoch_array+patient_epoch_array
label_list=control_epoch_labels+patient_epoch_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-86b944b88028> in <cell line: 2>()
#       1 data_list=control_epoch_array+patient_epoch_array
# ----> 2 label_list=control_epoch_labels+patient_epoch_labels
#
# NameError: name 'control_epoch_labels' is not defined

# %%
group_list=[[i] * len(j) for i, j in enumerate(data_list)]
len(group_list)

# %%
data_array=np.vstack(data_list)
label_array=np.hstack(label_list)
group_array=np.hstack(group_list)
print(data_array.shape, label_array.shape, group_array.shape)
