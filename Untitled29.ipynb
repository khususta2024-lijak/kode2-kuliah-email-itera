# %%
# Install necessary libraries
# !pip install mne numpy pandas

import mne
import numpy as np
import pandas as pd
from google.colab import files
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/TA
# Out:
# /content/drive/MyDrive/TA

# %%
file1 = "/content/drive/MyDrive/TA/chb01/chb01_03.edf"
data1 = mne.io.read_raw_edf(file1) # membaca file edf dan menyimpannya di data
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/TA/chb01/chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-4-1f34268e3d35>:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   data1 = mne.io.read_raw_edf(file1) # membaca file edf dan menyimpannya di data

# %%
import mne
import pandas as pd

# File EDF
file1 = "/content/drive/MyDrive/TA/chb01/chb01_03.edf"

# Membaca file EDF
data1 = mne.io.read_raw_edf(file1, preload=True)  # Preload digunakan agar data dibaca ke dalam memori

# Mendapatkan data dan informasi dari file EDF
data, times = data1.get_data(return_times=True)  # Mengambil data EEG dan waktu
channel_names = data1.ch_names  # Mendapatkan nama channel

# Membuat DataFrame dengan data EEG dan waktu
df = pd.DataFrame(data.T, columns=channel_names)  # Transpose data sehingga sesuai dengan format DataFrame
df['Time'] = times  # Menambahkan kolom waktu

# Menyimpan ke file CSV
csv_file = "/content/drive/MyDrive/TA/chb01/chb01_03.csv"
df.to_csv(csv_file, index=False)

print(f"Data berhasil disimpan dalam file CSV: {csv_file}")
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/TA/chb01/chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-6-84a7980220ed>:8: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   data1 = mne.io.read_raw_edf(file1, preload=True)  # Preload digunakan agar data dibaca ke dalam memori
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# Data berhasil disimpan dalam file CSV: /content/drive/MyDrive/TA/chb01/chb01_03.csv

# %%
import pandas as pd

# Path ke file CSV
csv_file = "/content/drive/MyDrive/TA/chb01/chb01_03.csv"

# Membaca file CSV
df = pd.read_csv(csv_file)

# Menampilkan 5 baris pertama
print(df.head())
# Out:
#          FP1-F7         F7-T7         T7-P7         P7-O1        FP1-F3  \
# 0 -1.777778e-05  3.926740e-05 -3.711844e-06  8.400488e-06 -5.860806e-07
# 1  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07
# 2  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07
# 3  5.860806e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07
# 4  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07
#
#           F3-C3         C3-P3         P3-O1        FP2-F4         F4-C4  ...  \
# 0  4.102564e-06  3.770452e-05 -1.504274e-05 -1.738706e-05 -4.512821e-05  ...
# 1  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  ...
# 2  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  ...
# 3  1.953602e-07  5.860806e-07 -1.953602e-07  1.953602e-07  5.860806e-07  ...
# 4  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  1.953602e-07  ...
#
# ...

# %%
import csv

#field names
fields = ['chb01_03.edf']

#data rows of csv file
F_simpan=np.array(F)
rows = [F_simpan]

# name of csv file
filename = "ekstraksi chb01_03.csv"

#writing to csv file
with open(filename, 'w') as csvfile:

  # creating a csv writer object
  csvwriter = csv.writer(csvfile)

  # writing the fields
  csvwriter.writerow(fields)

  # writing the data rows
  csvwriter.writerows(rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fbd60d2c99b5> in <cell line: 7>()
#       5
#       6 #data rows of csv file
# ----> 7 F_simpan=np.array(F)
#       8 rows = [F_simpan]
#       9
#
# NameError: name 'F' is not defined
