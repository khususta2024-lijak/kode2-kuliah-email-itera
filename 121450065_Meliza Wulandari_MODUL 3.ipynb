# %% [markdown]
# # Exercise 11: Asking Questions

# %% [markdown]
# ## Jelaskan maksud kode per baris

# %%
#mengoutputkan, tapi tidak baris baru
print("How old are you?", end=' ')
age = input()
print("How tall are you?", end=' ')
height = input()
print("How much do you weight?", end=' ')
weight = input()

print(f"So, you're {age} old, {height} tall and {weight} heavy.")
# Out:
# How old are you? 18
# How tall are you? 158
# How much do you weight? 50
# So, you're 18 old, 158 tall and 50 heavy.

# %% [markdown]
# ## Ada yang aneh? Apakah fungsi dari kode **input()**?
# fungsi kode input() yaitu perintah memasukan data ke dalam suatu variabel yang dapat dipanggil kembali

# %% [markdown]
# ## Apakah tipe data bawaan dari **input()**?
# tipe data bawaan dari input() adalah string (str) walaupun data yang dimasukan bertipe selain string, ketika menggunakan fungsi input() akan berubah ke str

# %%
type(age)
# Out:
# str

# %% [markdown]
# ## Apakah fungsi dari **end=' '**?
# fungsinya yaitu digunakan untuk menghasilkan output dalam satu baris

# %% [markdown]
# ## Apakah ada cara lain untuk mendapatkan input dari pengguna selain menggunakan **input()** ? Contohkan!
# tidak ada cara lain, karena untuk mendapaatkan input dari penggguna hanya dengan fungsi input()

# %% [markdown]
# ## [Referensi](https://www.programiz.com/python-programming/input-output-import)

# %% [markdown]
# # Exercise 12: Prompting People

# %% [markdown]
# ## Jelaskan maksud kode per baris

# %%
age = input("How old are you? ")#Perintah mengoutputkan tanpa menggunakan print, sekaligus meminta pengguna menginputkan data yang kemudian disimpan dalam suatu variabel
height = input("How tall are you? ")#Perintah mengoutputkan tanpa menggunakan print, sekaligus meminta pengguna menginputkan data yang kemudian disimpan dalam suatu variabel
weight = input("How much do you weight? ")#Perintah mengoutputkan tanpa menggunakan print, sekaligus meminta pengguna menginputkan data yang kemudian disimpan dalam suatu variabel

print(f"So, you're {age} old, {height} tall and {weight} heavy.")#Perintah print menggunakan format string, untuk menampilkan data sekaligus memanggil variabel

# %% [markdown]
# ## Ketika kita memasukkan nilai ke dalam ( ), akan menghasilkan apa?
# akan mengoutputkan tanpa menggunakan perintah print, sekaligus menginputkan sebuah nilai yang disimpan kedalam sebuah variable.

# %% [markdown]
# ## Apakah cara seperti ini dapat dilakukan? Praktekkan!
#
#
# ```
# print("How old are you?" , input())?
# ```

# %%
print("how old are you", input())?

# %% [markdown]
# cara tersebut setelah dilakukan akan terjadi error, solusinya hapus tanda tanya (?) supaya program dapat dijalankan

# %% [markdown]
# # Exercise 13: Parameters, Unpacking, Variables
# Apa yang akan kita lakukan sekarang adalah menulis script yang dapat menerima argumen

# %% [markdown]
# ## Jelaskan maksud kode per baris (jangan jalankan di .ipynb)

# %%
from sys import argv #mengimport argument variabel dari library sys

# read the WYSS section for how to run this
script, first, second, third = argv ##membuat beberapa argument (script, first, second, third) dan memasukkannya ke dalam argument variable

print("The script is called:", script) # mengoutputkan sekaligus memanggil kembali nilai variable
print("Your first variable is:", first) # mengoutputkan sekaligus memanggil kembali nilai variable
print("Your second variable is:", second) # mengoutputkan sekaligus memanggil kembali nilai variable
print("Your third variable is:", third) # mengoutputkan sekaligus memanggil kembali nilai variable

# %% [markdown]
# ## Buatlah file dengan nama ex13.py, kemudian salin kode di atas. Pindah ke direktori file, kemudian jalankan kode di bawah. Apakah berhasil? Apa yang terjadi?
#
#
# ```
# python .\ex13.py Kalian Semua Keren
# ```

# %% [markdown]
# ## Coba masukkan kode seperti di atas, namun kurangi atau lebihkan argumen yang kalian berikan. Apa yang terjadi?

# %% [markdown]
# terjadi error karena jumlah variabel yang dimasukan tidak sesuai

# %% [markdown]
# ## Buatlah suatu program yang menerima argv dan input secara bersamaan!

# %%
from sys import argv
script, nama, nim, prodi, kelas = argv

print("The sript is called :", script)
print("Nama saya adalah", nama)
print("nim saya yaitu", nim)
print("Prodi saya yaitu", prodi)
print("Saya berasal dari kelas", kelas)

nilai = (input("Saya mendapat nilai"))
print(nilai)

# %% [markdown]
# ## Apakah library dan module adalah dua hal yang sama?

# %% [markdown]
# library dan module merupakan hal yang sama, jika sudah ada library atau module tidak perlu ngoding dari awal

# %% [markdown]
# # Exercise 14: Prompting And Passing

# %% [markdown]
# ## Jelaskan maksud kode per baris (jangan jalankan di .ipynb)

# %%
from sys import argv #mengimport argument variabel dari library sys 

script, user_name = argv #membuat beberapa variable dan memasukkannya ke dalam argument variable
prompt = '> ' #membuat variabel prompt yang berisi string

#mengoutputkan variabel
print(f"Hi {user_name}, I'm the {script} script.")
print("I'd like to ask you a few questions.")
print(f"Do you like me {user_name}?")
likes = input(prompt)

#lives = input('> ') menginputkan nilai ke sebuah variabel baru
print(f"Where do you live {user_name}?")
lives = input(prompt)

print("What kind of computer do you have?")
computer = input(prompt)#computer = input('> ') menginputkan nilai ke sebuah variabel baru

#memanggil/mengoutputkan variabel input baru
print(f"""
Alright, so you said {likes} about liking me.
You live in {lives}. Not sure where that is.
And you have a {computer} computer. Nice.
""")

# %% [markdown]
# ## Apakah kalian bisa menjalankan kode di atas? Bagaimana caranya?

# %% [markdown]
# Kode diatas dapat dijalankan, langkahnya sebagai berikut :
#
# Membuat file dengan nama ex14.py
# Menuliskan kode/salin kode pada file ex14.py
# Masuk ke cmd dan pindah direktori file ke folder yang berisi file ex14.py
# Kemudian jalankan dengan perintah->python ex.py user_name

# %% [markdown]
# ## Editlah kode di atas. Tambahkan argumen **last_name** dan gunakan itu pada script ketika kalian menjalankan programnya di Terminal/CMD!
#
# contohnya:
#
#
# ```
# python ex14.py dimas wahyu
# ```

# %%
from sys import argv

script, user_name, last_name = argv  #Menambahkan argumen last_name
prompt = '> '

print(f"Hi {user_name} {last_name}, I'm the {script} script.")
print("I'd like to ask you a few questions.")
print(f"Do you like me {user_name} {last_name}?")
likes = input(prompt)

print(f"Where do you live {user_name} {last_name}?")
lives = input(prompt)

print("What kind of computer do you have?")
computer = input(prompt)

print(f"""
Alright, so you said {likes} about liking me.
You live in {lives}. Not sure where that is.
And you have a {computer} computer. Nice.
""")

# %% [markdown]
# # Exercise 15: Reading Files
# Hati-hati, dapat menghapus berkas kalian. Jalankan pada cmd/terminal.
#
# Latihan ini melibatkan penulisan dua file. Salah satunya adalah file ex15.py biasa yang akan Anda jalankan, tetapi yang lain diberi nama ex15_sample.txt. File kedua ini bukan skrip tetapi file teks biasa yang akan kita baca.

# %% [markdown]
# ## file ex15_sample.txt (buat di notepad)
#
#
#
# ```
# This is stuff I typed into a file.
# It is really cool stuff.
# Lots and lots of fun to have in here.
# ```

# %% [markdown]
# ## Jelaskan maksud kode per baris (jangan di .ipynb, jalankan di script mode)

# %%
from sys import argv

script, filename = argv #untuk membuat beberapa variabel dan dimasukkan ke dalam argument variable

txt = open(filename) #untuk membuka file txt

print(f"Here's your file {filename}:") #mengoutput string dari "filename" dengan menggunakan format f
print(txt.read()) #untuk output isi text yang ada di file txt tersebut 

print("Type the filename again:") #output kalimat berformat string
file_again = input("> ") #ouput string simbol dan meminta input variabel dari user
txt_again = open(file_again) #membuka kembali file txt

print(txt_again.read()) #mencetak kembali isi dari file txt

# %% [markdown]
# ## [Referensi](https://www.w3schools.com/python/ref_func_open.asp)

# %% [markdown]
# # Exercise 16: Reading And Writing Files
# Jangan jalankan di .ipynb
#
#
# ```
# • close – Closes the file. Like File->Save.. in your editor.
# • read – Reads the contents of the file. You can assign the result to a variable.
# • readline – Reads just one line of a text file.
# • truncate – Empties the file. Watch out if you care about the file.
# • write('stuff') – Writes ”stuff” to the file.
# • seek(0) – Move the read/write location to the beginning of the file.
# ```

# %% [markdown]
# ## Buatlah file test.txt, dengan isi,
#
#
# ```
# Halo ini hanya contoh
# ini baris kedua
# ini baris ketiga
# ```

# %% [markdown]
# ## Jelaskan maksud kode per baris (jangan jalankan di file .ipynb)

# %%
from sys import argv #mengimport argument pada variabel dari library sys

script, filename = argv #Membuat dua argumen (script, filename) dan memasukannya dalam argumen variabel

print(f"We're going to erase {filename}.")#user diminta untuk memasukan nama file yang ingin dihapus
print("If you don't want that, hit CTRL-C (^C).")
print("If you do want that, hit RETURN.")

input("?")

print("Opening the file...")
target = open(filename, 'w') # baris 8 membuka file dan masuk ke mode write


print("Truncating the file. Goodbye!")
target.truncate()

print("Now I'm going to ask you for three lines.")
#menuliskan kembali 3 baris isi file yang telah dihapus
line1 = input("line1: ")
line2 = input("line2: ")
line3 = input("line3: ")

print("I'm going to write these to the file.")

target.write(line1)#memanggil variabel line1
target.write("\n")
target.write(line2)#memanggil variabel line2
target.write("\n")
target.write(line3)#memanggil variabel line3
target.write("\n")

print("And finally, we close it.")
target.close()

# %% [markdown]
# ## Lihat pada baris 8. Cari tahu kenapa kita harus menambhkan 'w' sebagai parameter tambahan untuk membuka!

# %% [markdown]
# karena 'w' adalah mode untuk menuliskan sesuatu ke dalam file, jika tidak menggunakannya kita tidak bisa menuliskan atau mengedit isi file.

# %% [markdown]
# ## Selain menggunakan 'w', apa saja yang dapat kita gunakan?

# %% [markdown]
# yang dapat kita gunakan yaitu menggunakan append 'a', untuk menambahkan teks

# %% [markdown]
# ## Terlalu banyak pengulangan dalam file ini. Gunakan string, format, dan escape character untuk mencetak line1, line2, dan line3 hanya dengan satu perintah target.write(), bukan enam.

# %% [markdown]
# ## Tulis skrip yang mirip dengan latihan terakhir yang menggunakan read dan argv untuk membaca file yang baru saja Anda buat.

# %%
target.write(f"{line1}\n{line2}\n{line3}")

# %% [markdown]
# ## [Referensi](https://www.programiz.com/python-programming/file-operation)

# %% [markdown]
# # Exercise 17: More Files
# Jangan jalankan di .ipynb

# %% [markdown]
# ## Langkah pertama, buka cmd. Kemudian, buat file dengan cara
# `echo "This is a test file." > test.txt`

# %% [markdown]
# ## Kemudian lihat file yang telah dibuat, dengan cara
# `cat test.txt`

# %% [markdown]
# ## Jelaskan maksud kode per baris, dan jalankan!

# %%
from os.path import exists #mengimport exists dari library os.path
from sys import argv #mengimport argument variabel dari library sys

script, from_file, to_file = argv #Membuat tiga argumen (script, form_file, to_file) dan memasukannya ke argument variable

print(f"Copying from {from_file} to {to_file}") #Menampilkan sekaligus memanggil nilai variabel form_file dan to_file

# we could do these two on one line too, how?
in_file = open(from_file) #Membuka file awal
indata = in_file.read() #mode read

print(f"The input file is {len(indata)} bytes long") #menampilkan panjang byte data

print(f"Does the output file exists? {exists(to_file)}")#mengecek file copy/ file baru
print("Ready, hit RETURN to continue, CTRL-C to abort.")
input()

out_file = open(to_file, 'w')#membuka file copy dan menggunakan mode write atau 'w'
out_file.write(indata)

print("Alright, all done.")

#menutup file
out_file.close()
in_file.close()

# %% [markdown]
# ## Apakah kalian bisa membuat kode di atas menjadi lebih ringkas? Misanya satu baris? Coba yaaa!

# %%
from os.path import exists # mengimport exists dari library os.path
from sys import argv # mengimport argument variabel dari library sys

script, from_file, to_file = argv #membuat argument dan memasukannya ke argument variabel

print(f"Copying from {from_file} to {to_file}") #mengcopy file

in_file = open(from_file).read().len()

out_file = open(to_file, 'w').write()

out_file.close()
in_file.close()

# %% [markdown]
# ## Cari tahu mengapa Anda harus menulis out_file.close() dalam kode.

# %% [markdown]
# Metode file python close() menutup file yang dibuka. File yang ditutup tidak dapat dibaca atau ditulis lagi. Operasi apapun, yang mengharuskan file dibuka akn meningkatkan ValueError setelah file ditutup. Maka untuk itu perlu dilakukan untuk mengurangi value error.

# %% [markdown]
# # Exercise 18: Names, Variables, Code, Functions

# %% [markdown]
# ## Jelaskan maksud kode per baris

# %%
# this one is like your scripts with argv
def print_two(*args): #asterisk argument(*args) sama seperti argument variabel. fungsi dari * adalah menjadikan variabel-variabel nya menjadi list
    arg1, arg2 = args
    print(f"arg1: {arg1}, arg2: {arg2}")

#print_two('dimas', 'wahyu', 'saputro')
#['dimas', 'wahyu', 'saputro']
#ok, that *args is actually pointless, we can just do this
def print_two_again(arg1, arg2): #param -> ketika dideklarasikan
    print(f"arg1: {arg1}, arg2: {arg2}")


# this just takes one argument
def print_one(arg1):
    print(f"arg1: {arg1}")


# this one takes no arguments
def print_none():
    print("I got nothin'.")


print_two("Zed", "Shaw") # argumen -> ketika dipanggil
print_two_again("Zed", "Shaw")
print_one("First!")
print_none()

# %% [markdown]
# ## Write these checks on an index card and keep it by you while you complete the rest of these exercises
#
# 1. Did you start your function definition with def?
# 2. Does your function name have only characters and _ (underscore) characters?
# 3. Did you put an open parenthesis ( right after the function name?
# 4. Did you put your arguments after the parenthesis ( separated by commas?
# 5. Did you make each argument unique (meaning no duplicated names)?
# 6. Did you put a close parenthesis and a colon ): after the arguments?
# 7. Did you indent all lines of code you want in the function four spaces? No more, no less.
# 8. Did you ”end” your function by going back to writing with no indent (dedenting we call it)?

# %% [markdown]
# Ya, benar. singkatan dari definition => def
# Ya, benar karena karakter akan terbaca dengan teknik tersebut, jika tidak menggunakan underscore maka yang terjadi akan error pada saat pemrosesan
# Ya, karena itu merupakan bagian penting dalam membuat fungsi () dan dapat diisi oleh parameter
# Ya, karena akan diletakan parameter didalamnya
# Ya, karena ketika ada argumen yang sama maka python mengindikasi sebagai 1 variabel juga
# Ya, saya meletakkan tanda kurung tutup dan titik dua setelah argumen
# Ya, benar karena pada saat membuat function maka isi parameter yang didalam function tersebut akan menjadi tab (4 spasi) didalamnya.
# Tidak, harus dengan indent agar tidak terjadi error function

# %%
def my_name(string):
  pass

# %% [markdown]
# ## When you run (”use” or ”call”) a function, check these things:
#
# 1. Did you call/use/run this function by typing its name?
# 2. Did you put the ( character after the name to run it?
# 3. Did you put the values you want into the parenthesis separated by commas?
# 4. Did you end the function call with a ) character?

# %% [markdown]
# Jawab:
#
# 1. Memanggil (Call) fungsi tersebut
# 2. Benar karena value tersebut akan di proses dalam algoritma dalam function
# 3. Benar, karena dalam python kita dapat memisahkan dalam memanggil function / value dengan dipisahkan oleh koma
# 4. Iya benar sekali, jika tidak maka akan error function

# %% [markdown]
# ## Warm Up

# %% [markdown]
# #### LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers *if* both numbers are even, but returns the greater if one or both numbers are odd
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(a,b):
    if a%2 == 0 and b%2 == 0:
        return min(a,b)
    else:
        return max(a,b)

# %%
# Check
lesser_of_two_evens(2,4)

# %%
# Check
lesser_of_two_evens(2,5)

# %% [markdown]
# #### ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
#     animal_crackers('Levelheaded Llama') --> True
#     animal_crackers('Crazy Kangaroo') --> False

# %%
def animal_crackers(text):
    wordlist = text.split()
    return wordlist[0][0] == wordlist[1][0]

# %%
# Check
animal_crackers('Levelheaded Llama')

# %%
# Check
animal_crackers('Crazy Kangaroo')

# %% [markdown]
# #### MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 *or* if one of the integers is 20. If not, return False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def makes_twenty(a,b):
    if a == 20 or b == 20 or (a+b)== 20:
        return True
    else:
        return False

# %%
# Check
makes_twenty(20,10)

# %%
# Check
makes_twenty(2,3)

# %% [markdown]
# ## Problems

# %% [markdown]
# #### OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
def old_macdonald(name): 
    if len(name) > 3:
        return name[:3].capitalize() + name[3:].capitalize()

# %%
# Check
old_macdonald('macdonald')

# %% [markdown]
# #### MASTER YODA: Given a sentence, return a sentence with the words reversed
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: The .join() method may be useful here. The .join() method allows you to join together strings in a list with some connector string. For example, some uses of the .join() method:
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# This means if you had a list of words you wanted to turn back into a sentence, you could just join them with a single space string:
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def master_yoda(name): 
    return ' '.join(name.split()[::-1])

# %%
# Check
master_yoda('I am home')

# %%
# Check
master_yoda('We are ready')

# %% [markdown]
# #### ALMOST THERE: Given an integer n, return True if n is within 10 of either 100 or 200
#
#     almost_there(90) --> True
#     almost_there(104) --> True
#     almost_there(150) --> False
#     almost_there(209) --> True
#
# NOTE: `abs(num)` returns the absolute value of a number

# %%
def almost_there(n):
    return ((abs(100- n) <= 10) or (abs(200 - n) <= 10))

# %%
# Check
almost_there(104)
# Out:
# True

# %%
# Check
almost_there(150)
# Out:
# False

# %%
# Check
almost_there(209)
# Out:
# True

# %% [markdown]
# # Exercise 19: Functions And Variables

# %% [markdown]
# ## Jelaskan maksud kode per baris

# %%
#Fungsi dengan value cheese_and_crackers dengan parameter cheese_count, boxes_of_crackers
def cheese_and_crackers(cheese_count, boxes_of_crackers):
    print(f"You have {cheese_count} cheeses!")#fungsi yang membaca cheese_count yang diinputkan
    print(f"You have {boxes_of_crackers} boxes of crackers!")#fungsi yang membaca boxes_of_crackers yang diinputkan
    print("Man that's enought for a party!")#Fungsi yang mencetak kalimat 
    print("Get a blanket.\n")# Fungsi yang mencetak kalimat 

#mencetak kalimat dengan menambahkan variabel valuenya = 20, 30 
print("We can just give the function numbers directly:")
cheese_and_crackers(20, 30)

#mencetak kalimat dengan menambahkan variabel amount_of_cheese, amount_of_crackers
print("OR, we can use variables from our script:")
amount_of_cheese = 10
amount_of_crackers = 50

#Memasukan amount_of_cheese dan amount_of_crackers dalam fungsi cheese_and_crackers,
cheese_and_crackers(amount_of_cheese, amount_of_crackers)

#mencetak kelimat dan assign cheese_and_crackers ke dalam persamaan matematis
print("We can even do math inside too:")
cheese_and_crackers(10 + 20, 5 + 6)

#mencetak kalimat dengan mengubah assign cheese_and_crackers dengan penammbahan 100 dan 1000
print("And we can combine the two, variables and math:")
cheese_and_crackers(amount_of_cheese + 100, amount_of_crackers + 1000)

# %% [markdown]
# # Exercise 20: Functions And Files
# Jangan jalankan di .ipynb

# %% [markdown]
# ## Jelaskan maksud kode per baris
# buat file baru, beri nama ex20.py

# %%
from sys import argv #Library yang mengimport argumen yang akan megeluarkan perintah dari sistem 

script, input_file = argv #Membaca script yang dissimpan dalam value input_file

#Fungsi dengan parameter f dengan perintah dalam untuk membaca
def print_all(f):
    print(f.read())

#Fungsi dengan parameter f dengan perintah dalam untuk melihat perintah dalam untuk melihat file
def rewind(f):
    f.seek(0)


def print_a_line(line_count, f):
    print(line_count, f.readline())

#Membuka file tersebut
current_file = open(input_file)

#Mencetak kalimat
print("First let's print the whole file:\n")

#memanggil parameter dari print_all
print_all(current_file)

#mencetak kalimat
print("Now let's rewind, kind of like a tape.")

#memanggil parameter dari rewind
rewind(current_file)

print("Let's print three lines:") #mencetak kalimat

current_line = 1 #menghitung baris pertama sama dengan satu
print_a_line(current_line, current_file) #fungsi yang menuliskan string ada berapa line


current_line = current_line + 1 #menambahkan baris per 1 line dan memasukan kedalam fungsi print_a_line
print_a_line(current_line, current_file)

current_line = current_line + 1 #kemudian menambahkan baris per 1 line dan memasukan kedalam fungsi print_a_line
print_a_line(current_line, current_file)

# %% [markdown]
# Jalankan code dengan cara
#
#
# ```
# python ex20.py test.txt
# ```
