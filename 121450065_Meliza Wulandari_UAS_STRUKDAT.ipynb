# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Koordinat:
	def __init__(self,x,y):
		self.z = 0
		self.x = x
		self.y = y
	def set_x(self,x):
		self.x = x
	def increment_x(self):
		self.x+=1
	def __str__(self):
		return f"x : {self.x} , y:{self.y} , z:{self.z}"

# %%
import math

# %%
class Koordinat:
  def __init__(self,x,y,z):
    self.x = x
    self.y = y
    self.z = z

  def setx(self, x):
    self.x = x
    
  def sety(self, y):
    self.y = y

  def setz(self, z):
    self.z = z


class Vektor(Koordinat):  
  def setKoordinat(self, Koordinat):
    self.Koordinat = Koordinat

  def getKoordinat(self):
    return self.Koordinat

  def norm(self):
    return math.sqrt(self.x**2 + self.y**2 + self.z**2)

  def __sub__(self, other):
    return Vektor(self.x - other.x, self.y - other.y, self.z - other.z)

  def __pow__(self, power):
    return Vektor(self.x**power, self.y**power, self.z**power)

  def __iter__(self):
    yield self.x
    yield self.y
    yield self.z    

  def euclidianDistance(self, other):
    return sum((self - other)**2)**0.5


a = Vektor(1,2,3)
hasil = a.norm()
print('Hasil Norm dari vektor a({},{},{}) adalah {}'.format(a.x,a.y,a.z,hasil))
# Out:
# Hasil Norm dari vektor a(1,2,3) adalah 3.7416573867739413

# %%
v1 = Vektor(2, 5, 3)
v2 = Vektor(0, 0, 1)

print("Euclidian Distance dari vektor A = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor A =  5.744562646538029

# %%
v1 = Vektor(5, 3, 0)
v2 = Vektor(0, 7, 2)

print("Euclidian Distance dari vektor B = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor B =  6.708203932499369

# %%
v1 = Vektor(3, 1, 8)
v2 = Vektor(2.5, 1.5, 1.9)

print("Euclidian Distance dari vektor C = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor C =  6.140846847137616

# %%
v1 = Vektor(5, 3, 0)
v2 = Vektor(10, 4, 1)

print("Euclidian Distance dari vektor D = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor D =  5.196152422706632

# %%
v1 = Vektor(3, 2, 0)
v2 = Vektor(6, 5, 3)

print("Euclidian Distance dari vektor E = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor E =  5.196152422706632

# %%
v1 = Vektor(2, 6, 4)
v2 = Vektor(8, 7, 6)

print("Euclidian Distance dari vektor F = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor F =  8.660254037844387

# %%
v1 = Vektor(3, 3, 3)
v2 = Vektor(6, 8, 1)

print("Euclidian Distance dari vektor G = ", v1.euclidianDistance(v2))
# Out:
# Euclidian Distance dari vektor G =  4.69041575982343

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Koordinat :
  def _init_ (self, x, y , z):
    self.x = x
    self.y = y
    self.z = z
  
  def setx(self):
    return self.x

  def sety(self):
    return self.y

  def setz(self):
    return self.z

class vector :
  def getKoordinat(self, setx,sety,setz):
    self.setx = setx
    self.sety = sety
    self.setz = setz

  def setKoordinat(self,k):
    koordinat = (k.setx(), k.sety(), k.setz())
    return koordinat

  def norm(self, a, b):
    sum = 0
    self.a = self.setKoordinat(a)
    self.b = self.setKoordinat(b)
    for n in range (3):
      sum = sum + (self.a[n]- self.b[n])**2
    return sum **0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

class Titik:
  pass

xyz1 = Titik()
xyz2 = Titik()

xyz1.x = float(input('Koordinat x dari titik pertama: ')) 
xyz1.y = float(input('Koordinat y dari titik pertama: ')) 
xyz1.z = float(input('Koordinat z dari titik pertama: '))

xyz2.x = float(input('Koordinat x dari titik kedua: ')) 
xyz2.y = float(input('Koordinat y dari titik kedua: ')) 
xyz2.z = float(input('Koordinat z dari titik kedua: '))

def dist(x1, y1, z1, x2, y2, z2):
  dist = math.sqrt((x1 - x2)**2 + (y1 - y2)**2 + (z1 - z2)*84
                   2)
  return dist

dist = dist(xyz1.x, xyz1.y, xyz1.z, xyz2.x, xyz2.y, xyz2.z)

print("Jarak euclidian antara 2 vector: " ,dist)
# Out:
# Koordinat x dari titik pertama: 4
# Koordinat y dari titik pertama: 5
# Koordinat z dari titik pertama: 6
# Koordinat x dari titik kedua: 7
# Koordinat y dari titik kedua: 8
# Koordinat z dari titik kedua: 5
# Jarak euclidian antara 2 vector:  10.0

# %% [markdown]
# 2. Buatlah program LinkedDeque berdasarkan konsep Double Linked List
# menggunakan ADT dibawah ini!

# %%
class Deque:
  def _init_(self):
    self._data = []
    self._size = 0
  
  def _len_(self):
    return self._size

  def isempty(self):
    return len(self._data) == 0
  
  @property
  def view(self):
    return self._data
 
  def first(self):
    return self._data[0]
  
  def last(self):
    return self._data[-1]
  
  def add_first(self,item):
    self._data.append(item)
    self._data.insert(0,self._data.pop())
    self._size += 1
  
  def add_last(self,item):
    self._data.append(item)
    self._size += 1

  def delete_first(self):
    if self.isempty():
      raise Exception('Stack kosong')
    else:
      self._size -= 1
      return self._data.pop(0)

  def delete_last(self):
    if self.isempty():
      raise Exception('queue kosong')
    else:
      self._size -= 1
      return self._data.pop()

# %%
D = Deque()

# %%
D.add_last(5)
D.add_first(3)
D.add_first(7)
D.delete_last()
print(D.first())
print(D.first())
print(D.first())
print(D.first())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ef63cd063268> in <module>
# ----> 1 D.add_last(5)
#       2 D.add_first(3)
#       3 D.add_first(7)
#       4 D.delete_last()
#       5 print(D.first())
#
# <ipython-input-24-025fd9fb35d3> in add_last(self, item)
#      26
#      27   def add_last(self,item):
# ---> 28     self._data.append(item)
#      29     self._size += 1
#      30
#
# AttributeError: 'Deque' object has no attribute '_data'

# %% [markdown]
# 3. Terdapat urutan input data sebagai berikut : 20, 10, 40, 30, 35, 24, 33, 28, 34, 31.
# Buatlah program Binary Search Tree berdasarkan input data tersebut dan outputkan
# penelusuran secara In Order dan Post Order!

# %%
class BST:
    def _init_(self, key):
      self.key = key
      self.left = None
      self.right = None

# Inorder traversal
def inorder(root):
    if root is not None:
      # Traverse left
      inorder(root.left)
      # Traverse root
      print(str(root.key) + "->", end=' ')
      # Traverse right
      inorder(root.right)

# Preorder traversal
def preorder(root):
    if root is not None:
      # Traverse root
      print(str(root.key) + "->", end=' ')
      # Trverse left
      preorder(root.left)
      # Traverse right
      preorder(root.right)

# Postorder traversal
def postorder(root):
    if root is not None:
      # Traverse left
      postorder(root.left)
      # Traverse right
      postorder(root.right)
      # Traverse root
      print(str(root.key) + "->", end=' ')

# Insert a node
def insert(node, key):
  # Return a new node if the tree is empty
    if node is None:
        return BST(key)
    # Traverse to the right place and insert the node
    if key < node.key:
        node.left = insert(node.left, key)
    else:
        node.right = insert(node.right, key)
    return node
# Find the inorder successor
def minValueNode(node):
    current = node
    # Find the leftmost leaf
    while(current.left is not None):
      current = current.left
    return current

# Deleting a node
def deleteNode(root, key):
    # Return if the tree is empty
    if root is None:
        return root
 # Find the node to be deleted
    if key < root.key:
        root.left = deleteNode(root.left, key)
    elif(key > root.key):
        root.right = deleteNode(root.right, key)
    else:
 # If the node is with only one child or no child
        if root.left is None:
          temp = root.right
          root = None
          return temp
        elif root.right is None:
          temp = root.left
          root = None
          return temp
        # If the node has two children,
        # place the inorder successor in position of the node to be deleted
        temp = minValueNode(root.right)
        root.key = temp.key
        # Delete the inorder successor
        root.right = deleteNode(root.right, temp.key)
    return root

def search(root,key):
     
    if root is None:
      return False
    elif root.key == key:
      return True
 
    if root.key < key:
        return search(root.right,key)
   
    return search(root.left,key)

# %%
root = None
root = insert(root, 20)
root = insert(root, 10)
root = insert(root, 40)
root = insert(root, 30)
root = insert(root, 35)
root = insert(root, 24)
root = insert(root, 33)
root = insert(root, 28)
root = insert(root, 34)
root = insert(root, 31)

print("\nInorder Traversal: ", end="")
inorder(root)
print("\nPreorder Traversal: ", end="")
preorder(root)
print("\nPostorder Trversal: ", end="")
postorder(root)

print("\nDelete element 24")
root = deleteNode(root, 24)

print("\nInorder Traversal: ", end="")
inorder(root)

print("\nInsert elemen 24 ")
root = insert(root, 24)

print("\nInorder Traversal: ", end="")
inorder(root)
print("\n")
print(search(root, 31))
# Out:
# Inorder Traversal: 10-> 20-> 24-> 28-> 30-> 31-> 33-> 34-> 35-> 40->
# Preorder Traversal: 20-> 10-> 40-> 30-> 24-> 28-> 35-> 33-> 31-> 34->
# Postorder Trversal: 10-> 28-> 24-> 31-> 34-> 33-> 35-> 30-> 40-> 20->
# Delete element 24
#
# Inorder Traversal: 10-> 20-> 28-> 30-> 31-> 33-> 34-> 35-> 40->
# Insert elemen 24
#
# Inorder Traversal: 10-> 20-> 24-> 28-> 30-> 31-> 33-> 34-> 35-> 40->
#
# True

# %% [markdown]
# 4. Diketahui Graph G dibawah ini sebagai berikut. Lakukan penelusuran pada
# Graph G tersebut dimulai dari node S. Buatlah program Breadth First Search untuk
# mengoutputkan urutan node yang dikunjungi untuk setiap iterasi !
#
# ![image.png](data:image/png;base64,...)

# %%
peta =  {'A':set(['S','B','G']),
         'B':set(['A','F','K', 'S']),
         'S':set(['B','E', 'C', 'A', 'D',]),
         'D':set(['S','G','L', 'E']),
         'E':set(['D','S','J']),
         'F':set(['K', 'B']),
         'G':set(['A','L','K','M']),
         'H':set(['L','C', 'D']),
         'C':set(['H', 'S']),
          'M':set(['G', 'J']),
          'J':set(['E','M']),
          'K':set(['G','F','B']),
          'L':set(['G','H','D'])}

def bfs(graf, mulai, tujuan):
    queue = [[mulai]]
    visited = set()

    while queue:     
        jalur = queue.pop(0)
        state = jalur[-1]
        if state == tujuan:
            return jalur
        elif state not in visited:
            for cabang in graf.get(state, []):
                jalur_baru = list(jalur)
                jalur_baru.append(cabang) 
                queue.append(jalur_baru) 

            visited.add(state)
        isi = len(queue)
        if isi == 0:
            print("Tidak ditemukan")

bfs(peta, 'S', 'G')
# Out:
# ['S', 'D', 'G']

# %% [markdown]
# 5. Graph di atas merupakan representasi sederhana dari keterhubungan antar kota
# di suatu daerah. Setiap node menunjukkan satu kota. Keterhubungan antar kota ditunjukkan
# oleh busur di antara keduanya. Bilangan pada busur menyatakan jarak antar kedua kota yang
# dihubungkan oleh busur tersebut.
# Buatlah program mencari jarak terdekat dari S ke G menggunakan algoritma Dijkstra !

# %%
infinity = float('infinity')
mulai = 'S'
berhenti = 'G'

lokasi = {
    'A':{'S': 10, 'B' : 10},
    'B':{'S':25, 'A' : 10, 'F' : 5, 'K': 50},
    'C':{'S': 30, 'H':40},
    'D':{'H': 25,'L': 52, 'E' : 15, 'S' : 35},
    'E': {'D': 15,'J': 20, 'S' : 10},
    'F':{'B' : 5, 'K' : 40},
    'G':{'A' : 90, 'M': 80, 'L': 40, 'K': 30},
    'H':{'D': 25, 'C' : 40, 'L' : 25},
    'J':{'M' : 40, 'E' : 20},
    'K': {'F': 40, 'B': 50, 'G': 30},
    'L': {'H' : 25, 'D': 52, 'G': 40},
    'M': {'J': 40, 'G': 40},
    'S':{'A' : 10, 'E' : 10, 'B' : 35, 'C' : 30, 'B' : 25, 'D' : 35},
}

distance = {}   # distance = jarak yang perlu ditempuh
city= {}    # city = data lokasi
for node in lokasi: # looping data pendefinisian lokasi
  distance[node] = infinity # inisialisasi dist dengan nilai infinity (anggapannya node ini belum dikunjungi)
  city[node] = {} # inisialisasi key tanpa values

distance[mulai] = 0 # atur jarak pertama dengan nilai 0

def find_cheapest_node(distance,not_checked):
  lowest_dist = infinity
  cheapest_node = ''
  for node in distance:
    if node in not_checked and distance[node] <= lowest_dist:
      lowest_dist = distance[node] #value 
      cheapest_node = node #key
  return cheapest_node

not_checked = [node for node in distance]
node = find_cheapest_node(distance, not_checked)

dist = distance['S']
child_dist = lokasi['S']

while not_checked:
  dist = distance[node]
  child_dist = lokasi[node]
  for c in child_dist:
    if distance[c] > dist + child_dist[c]:
      distance[c] = dist + child_dist[c]
      city[c] = node
  
  not_checked.pop(not_checked.index(node))
  node = find_cheapest_node(distance, not_checked)

print(' ')
print(f'Jarak tempuh terpendek dari {mulai} ke {berhenti} sejauh {distance[berhenti]} m!')

if distance[berhenti] < infinity:
  rute = [berhenti]
  
  i = 0
  while mulai not in rute:
    rute.append(city[rute[i]])
    i += 1
  
  barrier = '>'
  print(barrier*50)
  print(f'Rutenya adalah {rute[::-1]}')

else:
  print('Rute tidak dapat ditemukan')
# Out:
#
# Jarak tempuh terpendek dari S ke G sejauh 95 m!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Rutenya adalah ['S', 'A', 'B', 'F', 'K', 'G']
