# %%
import matplotlib.pyplot as plt

# Data
xl = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
yl = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
x2 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
x3 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89]

# Visualisasi data
plt.figure(figsize=(12, 8))
plt.scatter(xl, yl, label='Set 1', color='blue')
plt.scatter(x2, y2, label='Set 2', color='green')
plt.scatter(x3, y3, label='Set 3', color='red')
plt.scatter(x4, y4, label='Set 4', color='orange')

# Menambahkan label sumbu
plt.xlabel('X')
plt.ylabel('Y')

# Menambahkan judul dan legenda
plt.title('Visualisasi Data dengan Scatter Plot')
plt.legend()

# Menampilkan plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
xl = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
yl = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
x2 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
x3 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89]

# Visualisasi data
plt.figure(figsize=(12, 8))
plt.scatter(xl, yl, label='Set 1', color='blue')
plt.scatter(x2, y2, label='Set 2', color='green')
plt.scatter(x3, y3, label='Set 3', color='red')
plt.scatter(x4, y4, label='Set 4', color='orange')

# Menambahkan label sumbu
plt.xlabel('X')
plt.ylabel('Y')

# Menambahkan judul dan legenda
plt.title('Visualisasi Data dengan Scatter Plot')
plt.legend()

# Menampilkan plot
plt.grid(True)
plt.show()
