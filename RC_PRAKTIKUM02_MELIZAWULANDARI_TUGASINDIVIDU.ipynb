# %%
# Nomor 1a
f = lambda x: x ** (1/3)
f(3)
# Out:
# 1.4422495703074083

# %%
# Nomor 1b
from math import *
g = lambda y: e**y+8**y
g(3)
# Out:
# 532.0855369231876

# %%
# Nomor 1c
from math import *
h = lambda x: 1 / ((x-5)**2)+15)**1/2
# Out:
#   File "<ipython-input-35-c202faad2486>", line 3
#     h = lambda x: 1 / ((x-5)**2)+15)**1/2
#                                    ^
# SyntaxError: unmatched ')'

# %%
# Nomor 2a map
nilai = [2, 4, 6]
hasil = list(map(f, nilai))
hasil
# Out:
# [1.2599210498948732, 1.5874010519681994, 1.8171205928321397]

# %%
# Nomor 2a list comprehensif
hasil_comprehensif = [x**(1/3) for x in nilai]
hasil_comprehensif
# Out:
# [1.2599210498948732, 1.5874010519681994, 1.8171205928321397]

# %%
# Nomor 2b map
nilai = [2, 4, 6]
hasil = list(map(g, nilai))
hasil
# Out:
# [71.38905609893065, 4150.5981500331445, 262547.4287934927]

# %%
# Nomor 2b list comprehensif
hasil_comprehensif = [e**y+8**y for y in nilai]
hasil_comprehensif
# Out:
# [71.38905609893065, 4150.5981500331445, 262547.4287934927]

# %%
# Nomor 3
from functools import reduce
product = reduce((lambda x,y : x*y), [2, 4, 6])
product
# Out:
# 48

# %%
# Nomor 4
from timeit import timeit
from functools import reduce

def f(x,y):
    return x**(1/3)
a1 = "reduce(f,range(10))"
timeit(a1, "from functools import reduce", globals={"f": f})
# Out:
# 1.9339628990001074

# %%
# Nomor 5
