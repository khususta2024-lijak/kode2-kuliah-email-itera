# %% [markdown]
# Dataset yang digunakan pada sesi 2 yaitu dataset spotify.csv. unduh dataset pada link berikut : http://bit.ly/45VVB6X.
#
# 1. Lakukan klasterisasi berdasarkan atribut duration_ms pada dataset spotify.csv menggunakan model K-Means dengan code yang ada pada file K-Means.ipynb. (25 poin) .
# 2. Lakukan klasifikasi berdasarkan atribut track_popularity menggunakan model Naïve Bayes dengan code yang ada pada file Bayes_Theorem.ipynb. (25 Poin)
#
# unduh code K-Means.ipynb dan Bayes_Theorem.ipynb pada link berikut : http://bit.ly/41bX7k2

# %%
df_spotify = pd.read_csv("")

# %%
plt.figure(1, figsize=(10,5))
sns.scatterplot(
    data=df_spotify,
    x="duration",
    y="music",
    hue=""
)
